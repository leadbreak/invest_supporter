# %%
# pip install tf-nightly
# Out:
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/cli/cmdoptions.py", line 26, in <module>
#     from pip._internal.models.format_control import FormatControl
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/models/format_control.py", line 5, in <module>
#     from pip._vendor.packaging.utils import canonicalize_name
#   File "/usr/local/lib/python3.6/dist-packages/pip/_vendor/packaging/utils.py", line 8, in <module>
#     from .version import InvalidVersion, Version
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 764, in get_code
#   File "<frozen importlib._bootstrap_external>", line 833, in get_data
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 5, in <module>
#     from pip._internal.main import main
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/main.py", line 13, in <module>
#     from pip._internal.cli.autocompletion import autocomplete
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/cli/autocompletion.py", line 11, in <module>
#     from pip._internal.cli.main_parser import create_main_parser
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/cli/main_parser.py", line 7, in <module>
#     from pip._internal.cli import cmdoptions
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
# KeyboardInterrupt

# %%
import tensorflow as tf
import tensorflow.keras.layers
from tensorflow.keras.layers import Input, LSTM, GRU, SimpleRNN, Dense, GlobalMaxPool1D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam, RMSprop

from sklearn.utils import shuffle

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # 1. SVM

# %%
df = pd.read_csv("/content/gdrive/My Drive/data_prj3/TSLA_dataset.csv")
df.info()

from sklearn.model_selection import train_test_split

X = df.iloc[:,1:7].values
y = df['result02'] 

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, random_state=0)

from sklearn.svm import SVC

svc4 = SVC(C = 25, gamma = 100, kernel = 'rbf') ##### 이거 동규씨가 보내준거 보고  수정 
svc4.fit(X_train, y_train)

print("훈련 정확도 :", svc4.score(X_train, y_train))
print("예측 정확도 :", svc4.score(X_test, y_test))

from sklearn.metrics import confusion_matrix

prediction = svc4.predict(X)
confusion = confusion_matrix(y_true=y, y_pred=prediction)
print("\n",confusion)

from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y, prediction, average="macro")
print("\nprecision_score :", precision)

recall = recall_score(y, prediction, average="macro")
print("recall_score :", recall)

f1_score0 = f1_score(y, prediction, average="macro")
print("f1_score :",f1_score0)

print("\n다섯 번째 파라미터 값을 적용합니다 ...\n")


from sklearn.svm import SVC

svc5 = SVC(C = 100, gamma = 25, kernel = 'rbf')
svc5.fit(X_train, y_train)

print("훈련 정확도 :", svc5.score(X_train, y_train))
print("예측 정확도 :", svc5.score(X_test, y_test))

from sklearn.metrics import confusion_matrix

prediction1 = svc5.predict(X)
confusion1 = confusion_matrix(y_true=y, y_pred=prediction1)
print("\n",confusion1)

from sklearn.metrics import precision_score, recall_score, f1_score

precision1 = precision_score(y, prediction1, average="macro")
print("\nprecision_score :", precision1)

recall1 = recall_score(y, prediction1, average="macro")
print("recall_score :", recall1)

f1_score1 = f1_score(y, prediction1, average="macro")
print("f1_score1 :",f1_score1)
print("\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      780 non-null    int64
#  1   pred1     780 non-null    float64
#  2   pred1r    780 non-null    float64
#  3   pred2     780 non-null    float64
#  4   pred2r    780 non-null    float64
#  5   pred3     780 non-null    float64
#  6   pred3r    780 non-null    float64
#  7   result01  780 non-null    float64
#  8   result02  780 non-null    int64
# dtypes: float64(7), int64(2)
# memory usage: 55.0 KB
# 훈련 정확도 : 0.7555555555555555
# 예측 정확도 : 0.717948717948718
#
#  [[131  67   3]
#  [ 43 155   1]
#  [ 15  69 296]]
#
# precision_score : 0.7374781359661085
# recall_score : 0.7365277114384
# f1_score : 0.725012056104493
#
# 다섯 번째 파라미터 값을 적용합니다 ...
#
# 훈련 정확도 : 0.7299145299145299
# 예측 정확도 : 0.6666666666666666
#
#  [[ 97  91  13]
#  [ 24 173   2]
#  [  8  85 287]]
#
# precision_score : 0.732657038684866
# recall_score : 0.7023989854132319
# f1_score1 : 0.6869692926438864

# %%
############################################333# m4

import math

a1 = confusion[0,0]
a2 = confusion[1,0]
a3 = confusion[2,0]

pr = int(precision*100)
re = int(recall*100)
f1 = int(f1_score0*100)
ac = int(svc4.score(X_test, y_test)*100)

a4 = a1+a2+a3
h1 = a1/a4*100
h1 = math.trunc(h1)
print (h1)

r1 = a2/a4*100
r1 = math.trunc(r1)
# print (r1)

list1 = [pr,re,ac,h1,r1]

# print(ac)

if f1 >= 70 :

    if h1 >= 70 :
        q1=("high return")

    elif h1 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r1 >= 5 :
        q2=("low risk")

    elif r1 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 신뢰할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다. 
    
    ''' .format(f1,ac,pr,re,q1,q2))

elif f1 >= 60:

    if h1 >= 70 :
        q1=("high return")

    elif h1 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r1 >= 5 :
        q2=("low risk")

    elif r1 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 참고할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다.
    
    ''' .format(f1,ac,pr,re,q1,q2))


else : 
    
    print( '''
이 기업은 재무적, 정기적 요인이 아닌 비정기적, 
우발적 요인에 영향을 받는 주식일 확률이 높습니다.''')


################################ m5

b1 = confusion1[0,0]
b2 = confusion1[1,0]
b3 = confusion1[2,0]

pr1 = int(precision1*100)
re1 = int(recall1*100)
f11 = int(f1_score1*100)
ac1 = int(svc5.score(X_test, y_test)*100)

b4 = b1+b2+b3
h2 = b1/b4*100
h2 = math.trunc(h2)
# print (h2)

r2 = b2/b4*100
r2 = math.trunc(r2)
# print (r2)

list1 = [pr,re,ac,h2,r2]

# print(ac)


if f1 >= 70 :

    if h2 >= 70 :
        q1=("high return")

    elif h2 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r2 >= 5 :
        q2=("low risk")

    elif r2 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 신뢰할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다. 
    
    ''' .format(f1,ac,pr,re,q1,q2))

elif f1 >= 60:

    if h2 >= 70 :
        q1=("high return")

    elif h2 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r2 >= 5 :
        q2=("low risk")

    elif r2 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 참고할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다.
    
    ''' .format(f1,ac,pr,re,q1,q2))


else : 
    
    print( '''
이 기업은 재무적, 정기적 요인이 아닌 비정기적, 
우발적 요인에 영향을 받는 주식일 확률이 높습니다.''')
# Out:
# 69
#
#
# 이 모델의 종합점수는 72 이며 신뢰할 수 있는 수준 입니다.
# 정확도는 71 , 정밀도는 73 , 재현률은 73 입니다.
# 특징은 middle return,low risk 입니다.
#
#
#
#
# 이 모델의 종합점수는 72 이며 신뢰할 수 있는 수준 입니다.
# 정확도는 71 , 정밀도는 73 , 재현률은 73 입니다.
# 특징은 high return,low risk 입니다.

# %%
df = pd.read_csv("/content/gdrive/My Drive/data_prj3/SBUX_dataset.csv")
df.info()

from sklearn.model_selection import train_test_split

X = df.iloc[:,1:7].values
y = df['result02'] 

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, random_state=0)

from sklearn.svm import SVC

svc4 = SVC(C = 100, gamma = 50, kernel = 'rbf')
svc4.fit(X_train, y_train)

print("훈련 정확도 :", svc4.score(X_train, y_train))
print("예측 정확도 :", svc4.score(X_test, y_test))

from sklearn.metrics import confusion_matrix

prediction = svc4.predict(X)
confusion = confusion_matrix(y_true=y, y_pred=prediction)
print("\n",confusion)

from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y, prediction, average="macro")
print("\nprecision_score :", precision)

recall = recall_score(y, prediction, average="macro")
print("recall_score :", recall)

f1_score = f1_score(y, prediction, average="macro")
print("f1_score :",f1_score0)

print("\n다섯 번째 파라미터 값을 적용합니다 ...\n")


from sklearn.svm import SVC

svc5 = SVC(C = 100, gamma = 100, kernel = 'rbf')
svc5.fit(X_train, y_train)

print("훈련 정확도 :", svc5.score(X_train, y_train))
print("예측 정확도 :", svc5.score(X_test, y_test))

from sklearn.metrics import confusion_matrix

prediction1 = svc5.predict(X)
confusion1 = confusion_matrix(y_true=y, y_pred=prediction1)
print("\n",confusion1)

from sklearn.metrics import precision_score, recall_score, f1_score

precision1 = precision_score(y, prediction1, average="macro")
print("\nprecision_score :", precision1)

recall1 = recall_score(y, prediction1, average="macro")
print("recall_score :", recall1)

f1_score1 = f1_score(y, prediction1, average="macro")
print("f1_score1 :",f1_score1)
print("\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      780 non-null    int64
#  1   pred1     780 non-null    float64
#  2   pred1r    780 non-null    float64
#  3   pred2     780 non-null    float64
#  4   pred2r    780 non-null    float64
#  5   pred3     780 non-null    float64
#  6   pred3r    780 non-null    float64
#  7   result01  780 non-null    float64
#  8   result02  780 non-null    int64
# dtypes: float64(7), int64(2)
# memory usage: 55.0 KB
# 훈련 정확도 : 0.9333333333333333
# 예측 정확도 : 0.8512820512820513
#
#  [[182  12   7]
#  [  6 170  21]
#  [  2  20 360]]
#
# precision_score : 0.9091046489347795
# recall_score : 0.9036083920719399
# f1_score : 0.725012056104493
#
# 다섯 번째 파라미터 값을 적용합니다 ...
#
# 훈련 정확도 : 0.947008547008547
# 예측 정확도 : 0.8512820512820513
#
#  [[183  13   5]
#  [  9 172  16]
#  [  0  17 365]]
#
# precision_score : 0.9167353344790437
# recall_score : 0.9130138633644967
# f1_score1 : 0.914657977242725

# %%
############################################333# m4

import math

a1 = confusion[0,0]
a2 = confusion[1,0]
a3 = confusion[2,0]

pr = int(precision*100)
re = int(recall*100)
f1 = int(f1_score0*100)
ac = int(svc4.score(X_test, y_test)*100)

a4 = a1+a2+a3
h1 = a1/a4*100
h1 = math.trunc(h1)
print (h1)

r1 = a2/a4*100
r1 = math.trunc(r1)
# print (r1)

list1 = [pr,re,ac,h1,r1]

# print(ac)

if f1 >= 70 :

    if h1 >= 70 :
        q1=("high return")

    elif h1 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r1 >= 5 :
        q2=("low risk")

    elif r1 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 신뢰할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다. 
    
    ''' .format(f1,ac,pr,re,q1,q2))

elif f1 >= 60:

    if h1 >= 70 :
        q1=("high return")

    elif h1 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r1 >= 5 :
        q2=("low risk")

    elif r1 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 참고할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다.
    
    ''' .format(f1,ac,pr,re,q1,q2))


else : 
    
    print( '''
이 기업은 재무적, 정기적 요인이 아닌 비정기적, 
우발적 요인에 영향을 받는 주식일 확률이 높습니다.''')


################################ m5

b1 = confusion1[0,0]
b2 = confusion1[1,0]
b3 = confusion1[2,0]

pr1 = int(precision1*100)
re1 = int(recall1*100)
f11 = int(f1_score1*100)
ac1 = int(svc5.score(X_test, y_test)*100)

b4 = b1+b2+b3
h2 = b1/b4*100
h2 = math.trunc(h2)
# print (h2)

r2 = b2/b4*100
r2 = math.trunc(r2)
# print (r2)

list1 = [pr,re,ac,h2,r2]

# print(ac)


if f1 >= 70 :

    if h2 >= 70 :
        q1=("high return")

    elif h2 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r2 >= 5 :
        q2=("low risk")

    elif r2 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 신뢰할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다. 
    
    ''' .format(f1,ac,pr,re,q1,q2))

elif f1 >= 60:

    if h2 >= 70 :
        q1=("high return")

    elif h2 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r2 >= 5 :
        q2=("low risk")

    elif r2 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 참고할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다.
    
    ''' .format(f1,ac,pr,re,q1,q2))


else : 
    
    print( '''
이 기업은 재무적, 정기적 요인이 아닌 비정기적, 
우발적 요인에 영향을 받는 주식일 확률이 높습니다.''')
# Out:
# 95
#
#
# 이 모델의 종합점수는 72 이며 신뢰할 수 있는 수준 입니다.
# 정확도는 85 , 정밀도는 90 , 재현률은 90 입니다.
# 특징은 high return,high risk 입니다.
#
#
#
#
# 이 모델의 종합점수는 72 이며 신뢰할 수 있는 수준 입니다.
# 정확도는 85 , 정밀도는 90 , 재현률은 90 입니다.
# 특징은 high return,high risk 입니다.

# %%
df = pd.read_csv("/content/gdrive/My Drive/data_prj3/AMD_dataset.csv")
df.info()

from sklearn.svm import SVC

svc4 = SVC(C = 50, gamma = 50, kernel = 'poly')
svc4.fit(X_train, y_train)

print("훈련 정확도 :", svc4.score(X_train, y_train))
print("예측 정확도 :", svc4.score(X_test, y_test))

from sklearn.metrics import confusion_matrix

prediction = svc4.predict(X)
confusion = confusion_matrix(y_true=y, y_pred=prediction)
print("\n",confusion)

from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y, prediction, average="macro")
print("\nprecision_score :", precision)

recall = recall_score(y, prediction, average="macro")
print("recall_score :", recall)

f1_score = f1_score(y, prediction, average="macro")
print("f1_score :",f1_score0)

print("\n다섯 번째 파라미터 값을 적용합니다 ...\n")



from sklearn.svm import SVC

svc5 = SVC(C = 10, gamma = 100, kernel = 'poly')
svc5.fit(X_train, y_train)

print("훈련 정확도 :", svc5.score(X_train, y_train))
print("예측 정확도 :", svc5.score(X_test, y_test))

from sklearn.metrics import confusion_matrix

prediction1 = svc5.predict(X)
confusion1 = confusion_matrix(y_true=y, y_pred=prediction1)
print("\n",confusion1)

from sklearn.metrics import precision_score, recall_score, f1_score

precision1 = precision_score(y, prediction1, average="macro")
print("\nprecision_score :", precision1)

recall1 = recall_score(y, prediction1, average="macro")
print("recall_score :", recall1)

f1_score1 = f1_score(y, prediction1, average="macro")
print("f1_score1 :",f1_score1)
print("\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      780 non-null    int64
#  1   pred1     780 non-null    float64
#  2   pred1r    780 non-null    float64
#  3   pred2     780 non-null    float64
#  4   pred2r    780 non-null    float64
#  5   pred3     780 non-null    float64
#  6   pred3r    780 non-null    float64
#  7   result01  780 non-null    float64
#  8   result02  780 non-null    int64
# dtypes: float64(7), int64(2)
# memory usage: 55.0 KB
# 훈련 정확도 : 0.8102564102564103
# 예측 정확도 : 0.7384615384615385
#
#  [[163  28  10]
#  [ 31 118  48]
#  [ 10  35 337]]
#
# precision_score : 0.7680392888208738
# recall_score : 0.7640429993616754
# f1_score : 0.725012056104493
#
# 다섯 번째 파라미터 값을 적용합니다 ...
#
# 훈련 정확도 : 0.7931623931623931
# 예측 정확도 : 0.7333333333333333
#
#  [[161  29  11]
#  [ 36 108  53]
#  [ 11  33 338]]
#
# precision_score : 0.7500428663620059
# recall_score : 0.7446783763520436
# f1_score1 : 0.7460289399464974

# %%
############################################333# m4

import math

a1 = confusion[0,0]
a2 = confusion[1,0]
a3 = confusion[2,0]

pr = int(precision*100)
re = int(recall*100)
f1 = int(f1_score0*100)
ac = int(svc4.score(X_test, y_test)*100)

a4 = a1+a2+a3
h1 = a1/a4*100
h1 = math.trunc(h1)
print (h1)

r1 = a2/a4*100
r1 = math.trunc(r1)
# print (r1)

list1 = [pr,re,ac,h1,r1]

# print(ac)

if f1 >= 70 :

    if h1 >= 70 :
        q1=("high return")

    elif h1 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r1 >= 5 :
        q2=("low risk")

    elif r1 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 신뢰할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다. 
    
    ''' .format(f1,ac,pr,re,q1,q2))

elif f1 >= 60:

    if h1 >= 70 :
        q1=("high return")

    elif h1 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r1 >= 5 :
        q2=("low risk")

    elif r1 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 참고할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다.
    
    ''' .format(f1,ac,pr,re,q1,q2))


else : 
    
    print( '''
이 기업은 재무적, 정기적 요인이 아닌 비정기적, 
우발적 요인에 영향을 받는 주식일 확률이 높습니다.''')


################################ m5

b1 = confusion1[0,0]
b2 = confusion1[1,0]
b3 = confusion1[2,0]

pr1 = int(precision1*100)
re1 = int(recall1*100)
f1 = int(f1_score1*100)
ac1 = int(svc5.score(X_test, y_test)*100)

b4 = b1+b2+b3
h2 = b1/b4*100
h2 = math.trunc(h2)
# print (h2)

r2 = b2/b4*100
r2 = math.trunc(r2)
# print (r2)

list1 = [pr,re,ac,h2,r2]

# print(ac)


if f1 >= 70 :

    if h2 >= 70 :
        q1=("high return")

    elif h2 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r2 >= 5 :
        q2=("low risk")

    elif r2 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 신뢰할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다. 
    
    ''' .format(f1,ac,pr,re,q1,q2))

elif f1 >= 60:

    if h2 >= 70 :
        q1=("high return")

    elif h2 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r2 >= 5 :
        q2=("low risk")

    elif r2 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 참고할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다.
    
    ''' .format(f1,ac,pr,re,q1,q2))


else : 
    
    print( '''
이 기업은 재무적, 정기적 요인이 아닌 비정기적, 
우발적 요인에 영향을 받는 주식일 확률이 높습니다.''')
# Out:
# 79
#
#
# 이 모델의 종합점수는 72 이며 신뢰할 수 있는 수준 입니다.
# 정확도는 73 , 정밀도는 76 , 재현률은 76 입니다.
# 특징은 high return,low risk 입니다.
#
#
#
#
# 이 모델의 종합점수는 74 이며 신뢰할 수 있는 수준 입니다.
# 정확도는 73 , 정밀도는 76 , 재현률은 76 입니다.
# 특징은 high return,low risk 입니다.

# %%
df = pd.read_csv("/content/gdrive/My Drive/data_prj3/INTC_dataset.csv")

from sklearn.svm import SVC

svc4 = SVC(C = 0.01, gamma = 100, kernel ='poly')
svc4.fit(X_train, y_train)

print("훈련 정확도 :", svc4.score(X_train, y_train))
print("예측 정확도 :", svc4.score(X_test, y_test))

from sklearn.metrics import confusion_matrix

prediction = svc4.predict(X)
confusion = confusion_matrix(y_true=y, y_pred=prediction)
print("\n",confusion)

from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y, prediction, average="macro")
print("\nprecision_score :", precision)

recall = recall_score(y, prediction, average="macro")
print("recall_score :", recall)

f1_score = f1_score(y, prediction, average="macro")
print("f1_score :",f1_score0)

print("\n다섯 번째 파라미터 값을 적용합니다 ...\n")


from sklearn.svm import SVC

svc5 = SVC(C = 50, gamma = 25, kernel = 'poly')
svc5.fit(X_train, y_train)

print("훈련 정확도 :", svc5.score(X_train, y_train))
print("예측 정확도 :", svc5.score(X_test, y_test))

from sklearn.metrics import confusion_matrix

prediction1 = svc5.predict(X)
confusion1 = confusion_matrix(y_true=y, y_pred=prediction1)
print("\n",confusion1)

from sklearn.metrics import precision_score, recall_score, f1_score

precision1 = precision_score(y, prediction1, average="macro")
print("\nprecision_score :", precision1)

recall1 = recall_score(y, prediction1, average="macro")
print("recall_score :", recall1)

f1_score1 = f1_score(y, prediction1, average="macro")
print("f1_score1 :",f1_score1)
print("\n")
# Out:
# 훈련 정확도 : 0.7777777777777778
# 예측 정확도 : 0.6974358974358974
#
#  [[153  35  13]
#  [ 34  95  68]
#  [  6  33 343]]
#
# precision_score : 0.7281768213433838
# recall_score : 0.7137777638503736
# f1_score : 0.725012056104493
#
# 다섯 번째 파라미터 값을 적용합니다 ...
#
# 훈련 정확도 : 0.8017094017094017
# 예측 정확도 : 0.7282051282051282
#
#  [[160  31  10]
#  [ 29 112  56]
#  [ 16  27 339]]
#
# precision_score : 0.7587827904422836
# recall_score : 0.7506607914176868
# f1_score1 : 0.753343642670235

# %%
############################################333# m4

import math

a1 = confusion[0,0]
a2 = confusion[1,0]
a3 = confusion[2,0]

pr = int(precision*100)
re = int(recall*100)
f1 = int(f1_score0*100)
ac = int(svc4.score(X_test, y_test)*100)

a4 = a1+a2+a3
h1 = a1/a4*100
h1 = math.trunc(h1)
print (h1)

r1 = a2/a4*100
r1 = math.trunc(r1)
# print (r1)

list1 = [pr,re,ac,h1,r1]

# print(ac)

if f1 >= 70 :

    if h1 >= 70 :
        q1=("high return")

    elif h1 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r1 >= 5 :
        q2=("low risk")

    elif r1 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 신뢰할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다. 
    
    ''' .format(f1,ac,pr,re,q1,q2))

elif f1 >= 60:

    if h1 >= 70 :
        q1=("high return")

    elif h1 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r1 >= 5 :
        q2=("low risk")

    elif r1 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 참고할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다.
    
    ''' .format(f1,ac,pr,re,q1,q2))


else : 
    
    print( '''
이 기업은 재무적, 정기적 요인이 아닌 비정기적, 
우발적 요인에 영향을 받는 주식일 확률이 높습니다.''')


################################ m5

b1 = confusion1[0,0]
b2 = confusion1[1,0]
b3 = confusion1[2,0]

pr1 = int(precision1*100)
re1 = int(recall1*100)
f1 = int(f1_score1*100)
ac1 = int(svc5.score(X_test, y_test)*100)

b4 = b1+b2+b3
h2 = b1/b4*100
h2 = math.trunc(h2)
# print (h2)

r2 = b2/b4*100
r2 = math.trunc(r2)
# print (r2)

list1 = [pr,re,ac,h2,r2]

# print(ac)


if f1 >= 70 :

    if h2 >= 70 :
        q1=("high return")

    elif h2 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r2 >= 5 :
        q2=("low risk")

    elif r2 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 신뢰할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다. 
    
    ''' .format(f1,ac,pr,re,q1,q2))

elif f1 >= 60:

    if h2 >= 70 :
        q1=("high return")

    elif h2 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r2 >= 5 :
        q2=("low risk")

    elif r2 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 참고할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다.
    
    ''' .format(f1,ac,pr,re,q1,q2))


else : 
    
    print( '''
이 기업은 재무적, 정기적 요인이 아닌 비정기적, 
우발적 요인에 영향을 받는 주식일 확률이 높습니다.''')
# Out:
# 79
#
#
# 이 모델의 종합점수는 72 이며 신뢰할 수 있는 수준 입니다.
# 정확도는 69 , 정밀도는 72 , 재현률은 71 입니다.
# 특징은 high return,low risk 입니다.
#
#
#
#
# 이 모델의 종합점수는 75 이며 신뢰할 수 있는 수준 입니다.
# 정확도는 69 , 정밀도는 72 , 재현률은 71 입니다.
# 특징은 high return,low risk 입니다.

# %%
df = pd.read_csv("/content/gdrive/My Drive/data_prj3/AMZN_dataset.csv")
df.info()


from sklearn.svm import SVC

svc4 = SVC(C = 25, gamma = 100, kernel = 'poly')
svc4.fit(X_train, y_train)

print("훈련 정확도 :", svc4.score(X_train, y_train))
print("예측 정확도 :", svc4.score(X_test, y_test))

from sklearn.metrics import confusion_matrix

prediction = svc4.predict(X)
confusion = confusion_matrix(y_true=y, y_pred=prediction)
print("\n",confusion)

from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y, prediction, average="macro")
print("\nprecision_score :", precision)

recall = recall_score(y, prediction, average="macro")
print("recall_score :", recall)

f1_score = f1_score(y, prediction, average="macro")
print("f1_score :",f1_score0)

print("\n다섯 번째 파라미터 값을 적용합니다 ...\n")



from sklearn.svm import SVC

svc5 = SVC(C = 50, gamma = 25, kernel = 'poly')
svc5.fit(X_train, y_train)

print("훈련 정확도 :", svc5.score(X_train, y_train))
print("예측 정확도 :", svc5.score(X_test, y_test))

from sklearn.metrics import confusion_matrix

prediction1 = svc5.predict(X)
confusion1 = confusion_matrix(y_true=y, y_pred=prediction1)
print("\n",confusion1)

from sklearn.metrics import precision_score, recall_score, f1_score

precision1 = precision_score(y, prediction1, average="macro")
print("\nprecision_score :", precision1)

recall1 = recall_score(y, prediction1, average="macro")
print("recall_score :", recall1)

f1_score1 = f1_score(y, prediction1, average="macro")
print("f1_score1 :",f1_score1)
print("\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      780 non-null    int64
#  1   pred1     780 non-null    float64
#  2   pred1r    780 non-null    float64
#  3   pred2     780 non-null    float64
#  4   pred2r    780 non-null    float64
#  5   pred3     780 non-null    float64
#  6   pred3r    780 non-null    float64
#  7   result01  780 non-null    float64
#  8   result02  780 non-null    int64
# dtypes: float64(7), int64(2)
# memory usage: 55.0 KB
# 훈련 정확도 : 0.7914529914529914
# 예측 정확도 : 0.7333333333333333
#
#  [[164  26  11]
#  [ 37 107  53]
#  [ 10  37 335]]
#
# precision_score : 0.74875398234458
# recall_score : 0.745343652305706
# f1_score : 0.725012056104493
#
# 다섯 번째 파라미터 값을 적용합니다 ...
#
# 훈련 정확도 : 0.8017094017094017
# 예측 정확도 : 0.7282051282051282
#
#  [[160  31  10]
#  [ 29 112  56]
#  [ 16  27 339]]
#
# precision_score : 0.7587827904422836
# recall_score : 0.7506607914176868
# f1_score1 : 0.753343642670235

# %%
############################################333# m4

import math

a1 = confusion[0,0]
a2 = confusion[1,0]
a3 = confusion[2,0]

pr = int(precision*100)
re = int(recall*100)
f1 = int(f1_score0*100)
ac = int(svc4.score(X_test, y_test)*100)

a4 = a1+a2+a3
h1 = a1/a4*100
h1 = math.trunc(h1)
print (h1)

r1 = a2/a4*100
r1 = math.trunc(r1)
# print (r1)

list1 = [pr,re,ac,h1,r1]

# print(ac)

if f1 >= 70 :

    if h1 >= 70 :
        q1=("high return")

    elif h1 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r1 >= 5 :
        q2=("low risk")

    elif r1 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 신뢰할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다. 
    
    ''' .format(f1,ac,pr,re,q1,q2))

elif f1 >= 60:

    if h1 >= 70 :
        q1=("high return")

    elif h1 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r1 >= 5 :
        q2=("low risk")

    elif r1 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 참고할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다.
    
    ''' .format(f1,ac,pr,re,q1,q2))


else : 
    
    print( '''
이 기업은 재무적, 정기적 요인이 아닌 비정기적, 
우발적 요인에 영향을 받는 주식일 확률이 높습니다.''')


################################ m5

b1 = confusion1[0,0]
b2 = confusion1[1,0]
b3 = confusion1[2,0]

pr1 = int(precision1*100)
re1 = int(recall1*100)
f1 = int(f1_score1*100)
ac1 = int(svc5.score(X_test, y_test)*100)

b4 = b1+b2+b3
h2 = b1/b4*100
h2 = math.trunc(h2)
# print (h2)

r2 = b2/b4*100
r2 = math.trunc(r2)
# print (r2)

list1 = [pr,re,ac,h2,r2]

# print(ac)


if f1 >= 70 :

    if h2 >= 70 :
        q1=("high return")

    elif h2 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r2 >= 5 :
        q2=("low risk")

    elif r2 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 신뢰할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다. 
    
    ''' .format(f1,ac,pr,re,q1,q2))

elif f1 >= 60:

    if h2 >= 70 :
        q1=("high return")

    elif h2 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r2 >= 5 :
        q2=("low risk")

    elif r2 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 참고할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다.
    
    ''' .format(f1,ac,pr,re,q1,q2))


else : 
    
    print( '''
이 기업은 재무적, 정기적 요인이 아닌 비정기적, 
우발적 요인에 영향을 받는 주식일 확률이 높습니다.''')
# Out:
# 77
#
#
# 이 모델의 종합점수는 72 이며 신뢰할 수 있는 수준 입니다.
# 정확도는 73 , 정밀도는 74 , 재현률은 74 입니다.
# 특징은 high return,low risk 입니다.
#
#
#
#
# 이 모델의 종합점수는 75 이며 신뢰할 수 있는 수준 입니다.
# 정확도는 73 , 정밀도는 74 , 재현률은 74 입니다.
# 특징은 high return,low risk 입니다.

# %%
df = pd.read_csv("/content/gdrive/My Drive/data_prj3/AAPL_dataset.csv")
df.info()

from sklearn.svm import SVC

svc4 = SVC(C = 15, gamma = 10, kernel = 'poly')
svc4.fit(X_train, y_train)

print("훈련 정확도 :", svc4.score(X_train, y_train))
print("예측 정확도 :", svc4.score(X_test, y_test))

from sklearn.metrics import confusion_matrix

prediction = svc4.predict(X)
confusion = confusion_matrix(y_true=y, y_pred=prediction)
print("\n",confusion)

from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y, prediction, average="macro")
print("\nprecision_score :", precision)

recall = recall_score(y, prediction, average="macro")
print("recall_score :", recall)

f1_score = f1_score(y, prediction, average="macro")
print("f1_score :",f1_score0)

print("\n다섯 번째 파라미터 값을 적용합니다 ...\n")


from sklearn.svm import SVC

svc5 = SVC(C = 0.1, gamma = 100, kernel = 'poly')
svc5.fit(X_train, y_train)

print("훈련 정확도 :", svc5.score(X_train, y_train))
print("예측 정확도 :", svc5.score(X_test, y_test))

from sklearn.metrics import confusion_matrix

prediction1 = svc5.predict(X)
confusion1 = confusion_matrix(y_true=y, y_pred=prediction1)
print("\n",confusion1)

from sklearn.metrics import precision_score, recall_score, f1_score

precision1 = precision_score(y, prediction1, average="macro")
print("\nprecision_score :", precision1)

recall1 = recall_score(y, prediction1, average="macro")
print("recall_score :", recall1)

f1_score1 = f1_score(y, prediction1, average="macro")
print("f1_score1 :",f1_score1)
print("\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      780 non-null    int64
#  1   pred1     780 non-null    float64
#  2   pred1r    780 non-null    float64
#  3   pred2     780 non-null    float64
#  4   pred2r    780 non-null    float64
#  5   pred3     780 non-null    float64
#  6   pred3r    780 non-null    float64
#  7   result01  780 non-null    float64
#  8   result02  780 non-null    int64
# dtypes: float64(7), int64(2)
# memory usage: 55.0 KB
# 훈련 정확도 : 0.7726495726495727
# 예측 정확도 : 0.6666666666666666
#
#  [[148  39  14]
#  [ 31  98  68]
#  [  5  41 336]]
#
# precision_score : 0.7195791250119793
# recall_score : 0.7044538295755567
# f1_score : 0.725012056104493
#
# 다섯 번째 파라미터 값을 적용합니다 ...
#
# 훈련 정확도 : 0.8
# 예측 정확도 : 0.7333333333333333
#
#  [[160  30  11]
#  [ 30 103  64]
#  [  4  30 348]]
#
# precision_score : 0.7597797146643425
# recall_score : 0.743285768163109
# f1_score1 : 0.7489816925975429

# %%
############################################333# m4

import math

a1 = confusion[0,0]
a2 = confusion[1,0]
a3 = confusion[2,0]

pr = int(precision*100)
re = int(recall*100)
f1 = int(f1_score0*100)
ac = int(svc4.score(X_test, y_test)*100)

a4 = a1+a2+a3
h1 = a1/a4*100
h1 = math.trunc(h1)
print (h1)

r1 = a2/a4*100
r1 = math.trunc(r1)
# print (r1)

list1 = [pr,re,ac,h1,r1]

# print(ac)

if f1 >= 70 :

    if h1 >= 70 :
        q1=("high return")

    elif h1 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r1 >= 5 :
        q2=("low risk")

    elif r1 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 신뢰할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다. 
    
    ''' .format(f1,ac,pr,re,q1,q2))

elif f1 >= 60:

    if h1 >= 70 :
        q1=("high return")

    elif h1 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r1 >= 5 :
        q2=("low risk")

    elif r1 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 참고할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다.
    
    ''' .format(f1,ac,pr,re,q1,q2))


else : 
    
    print( '''
이 기업은 재무적, 정기적 요인이 아닌 비정기적, 
우발적 요인에 영향을 받는 주식일 확률이 높습니다.''')


################################ m5

b1 = confusion1[0,0]
b2 = confusion1[1,0]
b3 = confusion1[2,0]

pr1 = int(precision1*100)
re1 = int(recall1*100)
f1 = int(f1_score1*100)
ac1 = int(svc5.score(X_test, y_test)*100)

b4 = b1+b2+b3
h2 = b1/b4*100
h2 = math.trunc(h2)
# print (h2)

r2 = b2/b4*100
r2 = math.trunc(r2)
# print (r2)

list1 = [pr,re,ac,h2,r2]

# print(ac)


if f1 >= 70 :

    if h2 >= 70 :
        q1=("high return")

    elif h2 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r2 >= 5 :
        q2=("low risk")

    elif r2 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 신뢰할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다. 
    
    ''' .format(f1,ac,pr,re,q1,q2))

elif f1 >= 60:

    if h2 >= 70 :
        q1=("high return")

    elif h2 >= 60:
        q1=("middle return")

    else :
        q1=("low return")


    if r2 >= 5 :
        q2=("low risk")

    elif r2 >= 15 :
        q2=("middle risk")

    else :
        q2=("high risk")

    print ('''
    
이 모델의 종합점수는 {} 이며 참고할 수 있는 수준 입니다.
정확도는 {} , 정밀도는 {} , 재현률은 {} 입니다.
특징은 {},{} 입니다.
    
    ''' .format(f1,ac,pr,re,q1,q2))


else : 
    
    print( '''
이 기업은 재무적, 정기적 요인이 아닌 비정기적, 
우발적 요인에 영향을 받는 주식일 확률이 높습니다.''')
# Out:
# 80
#
#
# 이 모델의 종합점수는 72 이며 신뢰할 수 있는 수준 입니다.
# 정확도는 66 , 정밀도는 71 , 재현률은 70 입니다.
# 특징은 high return,low risk 입니다.
#
#
#
#
# 이 모델의 종합점수는 74 이며 신뢰할 수 있는 수준 입니다.
# 정확도는 66 , 정밀도는 71 , 재현률은 70 입니다.
# 특징은 high return,low risk 입니다.
